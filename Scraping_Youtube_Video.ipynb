# %% [markdown]
# ## Scrapping Data
# Melakukan scrapping data terkait Clash of Champion by Ruangguru. hasil scrapping berupa komentar terkait video Clash of Champion yang tersedia di Youtube

# %%
# import library
import googleapiclient.discovery
import pandas as pd

# %%
# api key
API_KEY = "KEY"

# %%
# variable parameters
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = API_KEY

# %%
# create client api
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

# %%
def get_comments(client, videoId):
  youtube = client
  comments=[]
  nextPageToken = None

  while True:
    req = youtube.commentThreads().list(
        part='snippet',
        videoId=videoId,
        maxResults=100,
        pageToken=nextPageToken
    )

    res = req.execute()
    for item in res['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal']
      ])

    nextPageToken = res.get('nextPageToken')
    if not nextPageToken:
      break

  return pd.DataFrame(comments, columns=['author', 'dates', 'likes', 'Comments'])

# %%
# Melakukan Scraping data
id = "dY_3acmFFRQ"
df = get_comments(youtube, id)

# %%
df.head()
# Out:
#                      author                 dates  likes  \
# 0                @Ruangguru  2024-07-03T06:39:10Z   1448
# 1          @rizkifaisal5864  2024-07-14T05:31:54Z      0
# 2              @widyawid688  2024-07-14T05:31:50Z      1
# 3             @AswandiRedmi  2024-07-14T05:23:24Z      0
# 4  @jovitaitalianahimady432  2024-07-14T05:15:47Z      0
#
#                                             Comments
# 0  Yuk, konsultasi dan klaim diskonnya sekarang d...
# 1                                    Ada UPI gak sih
# 2  Semoga anak2ku kelak  bisa berprestasi kayak m...
# 3                Vibes nya kayak main squid game dah
# 4                                      KEREN ABIS❤️🔥

# %%
df.sort_values(by="likes", ascending=False).head(5)
# Out:
#                    author                 dates  likes  \
# 12756  @putriningtyas2868  2024-06-29T11:31:47Z  51857
# 12851  @destipramesti5010  2024-06-29T08:35:56Z  51108
# 10705      @MohammadArifM  2024-06-29T15:53:21Z  19908
# 12232           @yoloooow  2024-06-29T12:16:08Z  10840
# 9095         @vinaayu2092  2024-06-30T02:36:59Z   7930
#
#                                                 Comments
# 12756  tim yg ga pinter pinter bgt tp suka nonton org...
# 12851  PLEASEEEE VIRALIN ACARA INI, BIAR INDONESIA SE...
# 10705  Please acara gini jangan sampe ada settingan. ...
# 12232  LUCUU BGT SAMA KAKAK YG TAKUT DIHUJAT NETIZEN😭...
# 9095   Tolong buat editornya, jangan di skip atau dip...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12931 entries, 0 to 12930
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   author    12931 non-null  object
#  1   dates     12931 non-null  object
#  2   likes     12931 non-null  int64
#  3   Comments  12931 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 404.2+ KB

# %%
# simpan file
df.to_csv("Scraping_Youtube_Video.csv", index=False)
